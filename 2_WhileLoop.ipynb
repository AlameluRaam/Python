# %%
a=1
b=5
while a<b:
    print("A, B", a,b)
    a += 1
else:
    print("Out of while loop")
# Out:
# A, B 1 5
# A, B 2 5
# A, B 3 5
# A, B 4 5
# Out of while loop

# %%
a=1
b=5
while True:
    print("A, B", a,b)
    a += 1
    if a>4:
        break
else:
    print("Out of while loop")
# Out:
# A, B 1 5
# A, B 2 5
# A, B 3 5
# A, B 4 5
